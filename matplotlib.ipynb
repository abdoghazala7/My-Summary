# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# #  Ploting more than 1 variable on y-axis

# %%
x = np.arange(0,10) 

y1 = np.random.randint(1,100000,10)
plt.plot(x,y1)
y2 = np.random.randint(10,100000,10)
plt.plot(x,y2)
y3 = np.random.randint(100,100000,10)
plt.plot(x,y3)

plt.show()

# If plot looks not good enough, that is because that data is randomized

# %% [markdown]
# #  adding title , linestyle and legend to the plot

# %%
plt.plot(x,y1 , linestyle = '--')
plt.plot(x,y2)
plt.plot(x,y3)

plt.title('Relation between X and many Y variables')
plt.xlabel('X-axis data')
plt.ylabel('Y-axis data')

plt.legend(['y1','y2','y3'])

# %%
plt.plot(x,y1 , linestyle = '--')
plt.plot(x,y2)
plt.plot(x,y3)

plt.title('Relation between X and many Y variables')
plt.xlabel('X-axis data')
plt.ylabel('Y-axis data')

plt.legend(loc = 'upper left')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # bar plot

# %%
x = np.linspace(0,20,20)
y = np.random.randint(50,size = 20)
plt.bar(x,y)
# Out:
# <BarContainer object of 20 artists>

# %% [markdown]
# ### Histogram

# %%
data = np.random.randn(5000)
plt.hist(data ,bins = 20 ,alpha=0.5) 
plt.ylabel('Count',size = 15) # defualt
plt.show()

# %% [markdown]
# ### Pie

# %%
plt.pie([15,30,45,10], labels=('Egypt', 'Syria', 'Tunise', 'Morroco'), explode= [0,0,0,0.3], autopct= '%1.1f%%', shadow= True)
plt.axis('equal')
plt.show()

# %% [markdown]
# # Scatter

# %%
x = np.random.randint(1,16,30)
y = np.random.randint(1,16,30)
color_array = np.random.randint(1,16,30)

plt.scatter(x,y, s=100, c=color_array)  
plt.colorbar()
plt.show()

# %% [markdown]
# # subplot

# %%
plt.subplots(figsize=(20, 10))
# add_subplot(nrows, ncols, index)
plt.bar(x,y) 
plt.show()

# %% [markdown]
# # plot from pandas

# %%
df = pd.read_csv('data_for_visualizing1.csv', index_col='my_index')
df.hist(bins=30, figsize=(12, 8) , grid = True)
plt.show()
# Out:
# array([[<AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'balance'}>],
#        [<AxesSubplot:title={'center':'duration'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
df.head()
# Out:
#           age           job  marital  education  balance  duration  \
# my_index
# 0          58    management  married   tertiary     2143       261
# 1          44    technician   single  secondary       29       151
# 2          33  entrepreneur  married  secondary        2        76
# 3          47   blue-collar  married    unknown     1506        92
# 4          33       unknown   single    unknown        1       198
#
#               age_divided smoker travelled before    day
# my_index
# 0           old_customers    yes              yes  day 1
# 1           old_customers    yes               no  day 3
# 2         young_customers     no               no  day 2
# 3           old_customers    yes               no  day 1
# 4         young_customers     no              yes  day 4

# %%
from pandas.plotting import scatter_matrix

attributes = ["age", "balance", "duration"]
scatter_matrix(df[attributes], figsize=(12, 8))
plt.show()

# %%
import seaborn as sns 
sns.heatmap(df.corr() , linewidths= 2 , linecolor = 'white' )
# Out:
# <AxesSubplot:>

# %% [markdown]
# # <hr>
